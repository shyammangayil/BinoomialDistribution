# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#upvoted_afeelgoodnaswer_9661
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 200)
profileofupvoters  = pd.read_csv('C:\\Users\\DELL\\upvoted_afeelgoodnaswer_9661.csv',encoding='utf-8')

#profileofupvoters.shape
#profileofupvoters  =
profileofupvoters
# Out:
#                 Name nationality
# 0      Taksh Hadvani      Indian
# 1        Kiran Kumar      Indian
# 2     Arundhati Bose      Indian
# 3       Radha Venkat      Indian
# 4      Anisha Sharma      Indian
# ..               ...         ...
# 46      Rohit Sharma      Indian
# 47        Luis Arias       Greek
# 48  Sanchit Kathuria      Indian
# 49  Sheena Vemavaram      Indian
# 50      Dorell James  non-Indian
#
# [51 rows x 2 columns]

# %%
Indians = profileofupvoters[profileofupvoters.nationality=='Indian']

# %%
nonIndians = profileofupvoters[profileofupvoters.nationality!='Indian']

# %%
Indians.shape
len(Indians.index)
# Out:
# 33

# %%
nonIndians.shape
len(nonIndians.index)
# Out:
# 18

# %%
Indians.index
# Out:
# Int64Index([ 0,  1,  2,  3,  4,  5,  9, 11, 12, 13, 14, 15, 17, 18, 19, 23, 24,
#             25, 26, 27, 28, 31, 32, 33, 34, 36, 39, 40, 42, 44, 46, 48, 49],
#            dtype='int64')

# %%
import scipy.stats as stats


stats.probplot(Indians.index, dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()

# %%
import scipy.stats as stats


stats.probplot(nonIndians.index, dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()

# %%
from scipy.stats import binom
import seaborn as sb
##binom.rvs(size=10,n=20,p=0.8)

##data_binom = binom.rvs(n=20,p=0.8,loc=0,size=1000)
##ax = sb.distplot(data_binom,
##                  kde=True,
##                  color='blue',
##                  hist_kws={"linewidth": 25,'alpha':1})
##ax.set(xlabel='A Sample Binomial', ylabel='Frequency')

# %%
#import scipy.stats as ss

#n = 15         # Number of total bets
#p = 18./38     # Probability of getting "red" at the roulette
#max_sbets = 4  # Maximum number of successful bets

#hh = ss.binom(n, p)

#total_p = 0
#for k in range(1, max_sbets + 1):  # DO NOT FORGET THAT THE LAST INDEX IS NOT USED
#    total_p += hh.pmf(k)

# %%
from scipy.stats import binom
data_binom = binom.rvs(n=1,p=0.6470588235294118,size=9661)
data_binom
# Out:
# array([1, 0, 1, ..., 0, 0, 1])

# %%
ax = sb.distplot(data_binom,
                  kde=True,
                  color='blue',
                  hist_kws={"linewidth": 25,'alpha':1})
ax.set(xlabel='Binomial', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Binomial')]
